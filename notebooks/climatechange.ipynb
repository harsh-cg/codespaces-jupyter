# %% [markdown]
# ***Azure Notebooks Climate Change Analysis***

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import seaborn as sns; sns.set()

# %% [markdown]
# Data Creation

# %%
yearBase, meanBase = np.loadtxt('../data/5-year-mean-1951-1980.csv', delimiter=',', usecols=(0, 1), unpack=True)
year, mean = np.loadtxt('../data/5-year-mean-1882-2014.csv', delimiter=',', usecols=(0, 1), unpack=True)

# %% [markdown]
# Mean Temp Diff

# %%
plt.scatter(yearBase, meanBase)
plt.title("Mean Temp Diff")
plt.xlabel('years',fontsize=12)
plt.ylabel('mean',fontsize=12)
plt.savefig("../data/meantempdiff.png")

# %% [markdown]
# Mean Temp Diff w/t Trend Line

# %%
m,b = np.polyfit(yearBase, meanBase, 1)
def f(x):
    return m*x + b

plt.scatter(yearBase, meanBase)
plt.plot(yearBase, f(yearBase))
plt.title("Mean Temp Diff")
plt.xlabel('years',fontsize=12)
plt.ylabel('mean',fontsize=12)
plt.savefig("../data/meantempdiff(trendline).png")
plt.show()

print(' y = {0} * x + {1}'.format(m, b))
plt.show()
# Out:
#  y = 0.007279199110122221 * x + -14.309265850945222

# %% [markdown]
# Perform linear regression with scikit-learn

# %%
model = LinearRegression(fit_intercept=True)

yearbase_2d = yearBase[:, np.newaxis]
meanbase_2d = meanBase[:, np.newaxis]

model.fit(yearbase_2d, meanBase)
mean_predicted = model.predict(yearbase_2d)

plt.scatter(yearBase, meanBase)
plt.plot(yearBase, mean_predicted)
plt.title('scatter plot of mean temp difference vs year')
plt.xlabel('years', fontsize=12)
plt.ylabel('mean temp difference', fontsize=12)
plt.savefig("../data/meantempdiff(trendline_model).png")
plt.show()

print(' y = {0} * x + {1}'.format(model.coef_[0], model.intercept_))
# Out:
#  y = 0.007279199110122355 * x + -14.30926585094549

# %%
plt.scatter(year, mean)
plt.title('scatter plot of mean temp difference vs year')
plt.xlabel('years', fontsize=12)
plt.ylabel('mean temp difference', fontsize=12)
sns.regplot(x = yearBase,y = meanBase, ci = 95, scatter= False, fit_reg= True)
plt.show()
